# %% [markdown]
# Import the necessary libraries
# - To make an API request
# - To decode JSON
# - To save data to a dataframe
# - To interact with an SQL database

# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %% [markdown]
# ### Make a single API request and save the results to the nyt_article table

# %% [markdown]
# Set a variable to store the API endpoint URL

# %%
api_key = 'sgBFDFyjvlJyF1xsAcUDZUQV2neZzQ1r'
article_api_url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'

# %% [markdown]
# Set a dict of parameters to pass to the API endpoint URL

# %%
params = {'api-key':api_key, 'begin_date':'20190101', 'end_date':'20191231', 'q':'Los Angeles'}

# %% [markdown]
# Make an API GET request with the defined API endpoint URL and the dict of parameters

# %%
articles_request = requests.get(article_api_url, params=params)

# %% [markdown]
# Confirm the API request received a 200 HTTP status code

# %%
articles_request
# Out:
# <Response [200]>

# %% [markdown]
# View the text in the API request result

# %%
articles_request.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2020 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.","web_url":"https://www.nytimes.com/2019/12/21/style/la-fresh-poultry-immigrant-family-recipes.html","snippet":"LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.","lead_paragraph":"Betty Figueroa, 52, rides the 720 Wilshire rapid bus for more than two hours every morning from her apartment in the Koreatown neighborhood of Los Angeles to her housekeeping job in Brentwood. It takes her another two hours — depending on traffic — to get back to the apartment where she lives with her mother, Deborah Hernández, 80, and her two daughters each afternoon.","print_section":"ST","print_page":"4","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg","height":400,"width":600,"legacy":{"xlarge":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg","xlargewidth":600,"xlargeheight":400},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-popup.jpg","height":433,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog480.jpg","height":320,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog533.jpg","height":355,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog427.jpg","height":285,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagSF.jpg","height":241,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagArticle.jpg","height":395,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-slide.jpg","height":400,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-jumbo.jpg","height":683,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-superJumbo.jpg","height":1366,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","capti ...

# %% [markdown]
# Decode the API result text as JSON

# %%
json.loads(articles_request.text)
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.',
#     'web_url': 'https://www.nytimes.com/2019/12/21/style/la-fresh-poultry-immigrant-family-recipes.html',
#     'snippet': 'LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.',
#     'lead_paragraph': 'Betty Figueroa, 52, rides the 720 Wilshire rapid bus for more than two hours every morning from her apartment in the Koreatown neighborhood of Los Angeles to her housekeeping job in Brentwood. It takes her another two hours — depending on traffic — to get back to the apartment where she lives with her mother, Deborah Hernández, 80, and her two daughters each afternoon.',
#     'print_section': 'ST',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-superJumbo.jpg',
#       'height': 1366,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-horizontalMediumAt2X.jpg',
#       'height': 2667,
#       'width': 4000,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-hpLarge.jpg',
#       'height': 288,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbWide-v2.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbWide-v2.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoThumb-v2.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoLarge-v2.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo210-v2.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo225-v2.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo440-v2.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo252-v2.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo378-v2.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoLargeAt2X-v2.jpg',
#       'height': 1463,
#       'width': 2194,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoMediumAt2X-v2.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoSmallAt2X-v2.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine3000.jpg',
#       'height': 1688,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-watch268.jpg',
#       'height': 304,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'mobileMasterAt3x',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-mobileMasterAt3x.jpg',
#       'height': 1200,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mobileMasterAt3x',
#       'crop_name': 'mobileMasterAt3x'}],
#     'headline': {'main': 'The Store Where Los Angeles Converges',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Los Angeles',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Families and Family Life',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Chickens', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Restaurants', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Immigration and Emigration',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Egyptian-Americans',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Korean-Americans', 'rank': 6, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Hispanic-Americans',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Halal Foods and Products',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Al Salam Polleria (Los Angeles)',
#       'rank': 9,
#       'major': 'N'}],
#     'pub_date': '2019-12-21T11:00:17+0000',
#     'document_type': 'article',
#     'news_desk': 'Styles',
#     'section_name': 'Style',
#     'byline': {'original': 'By Jake Michaels and Walter Thompson-Hernández',
#      'person': [{'firstname': 'Jake',
#        'middlename': None,
#        'lastname': 'Michaels',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1},
#       {'firstname': 'Walter',
#        'middlename': None,
#        'lastname': 'Thompson-Hernández',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 2}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490',
#     'word_count': 1919,
#     'uri': 'nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490'},
#    {'abstract': 'As she finishes her first year as our California restaurant critic, Tejal Rao names the flavors she can’t forget from in and around the city.',
#     'web_url': 'https://www.nytimes.com/2019/12/09/dining/best-food-in-los-angeles.html',
#     'snippet': 'As she finishes her first year as our California restaurant critic, Tejal Rao names the flavors she can’t forget from in and around the city.',
#     'lead_paragraph': 'LOS ANGELES — Throughout my first year as a restaurant critic living in Los Angeles, zigzagging across the city in my car, I kept a running list of delicious things I wanted to tell you about. ',
#     'print_section': 'D',
#     'print_page': '11',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-superJumbo.jpg',
#       'height': 1365,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-horizontalMediumAt2X.jpg',
#       'height': 2333,
#       'width': 3500,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbWide-v2.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbWide-v2.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoThumb-v2.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoLarge-v2.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo210-v2.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo225-v2.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo440-v2.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo252-v2.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo378-v2.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-threeByTwoLargeAt2X-v2.jpg',
#       'height': 1986,
#       'width': 2980,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-threeByTwoMediumAt2X-v2.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
# ...
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoLargeAt2X.jpg',
#       'height': 2000,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-articleInline.jpg',
#       'height': 143,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-hpSmall.jpg',
#       'height': 122,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-blogSmallInline.jpg',
#       'height': 113,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumFlexible177.jpg',
#       'height': 133,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine3000.jpg',
#       'height': 1688,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'mobileMasterAt3x',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mobileMasterAt3x.jpg',
#       'height': 1350,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mobileMasterAt3x',
#       'crop_name': 'mobileMasterAt3x'}],
#     'headline': {'main': 'Where Does the House End and the Yard Begin?',
#      'kicker': 'On Location',
#      'content_kicker': None,
#      'print_headline': 'This Private Urban Oasis Lets the Outside In',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Real Estate and Housing (Residential)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Home Repairs and Improvements',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Los Angeles (Calif)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Restoration and Renovation',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Interior Design and Furnishings',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Furniture', 'rank': 6, 'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Studio City (Los Angeles, Calif)',
#       'rank': 7,
#       'major': 'N'}],
#     'pub_date': '2019-12-31T10:01:27+0000',
#     'document_type': 'article',
#     'news_desk': 'RealEstate',
#     'section_name': 'Real Estate',
#     'byline': {'original': 'By Tim McKeough',
#      'person': [{'firstname': 'Tim',
#        'middlename': None,
#        'lastname': 'McKeough',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/100c5fa3-3753-51aa-ab57-33e6c86ede74',
#     'word_count': 823,
#     'uri': 'nyt://article/100c5fa3-3753-51aa-ab57-33e6c86ede74'}],
#   'meta': {'hits': 4807, 'offset': 0, 'time': 256}}}

# %% [markdown]
# Assign the decoded API request JSON result to a variable

# %%
decoded_articles_request_text = json.loads(articles_request.text)

# %% [markdown]
# Print out the dictionary value for the key containing the list of articles in the decoded API request JSON result

# %%
decoded_articles_request_text['response']['docs']
# Out:
# [{'abstract': 'LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.',
#   'web_url': 'https://www.nytimes.com/2019/12/21/style/la-fresh-poultry-immigrant-family-recipes.html',
#   'snippet': 'LA Fresh Poultry, a halal-style butchery, caters to a diverse clientele of home chefs and professionals who want to be reminded of their roots.',
#   'lead_paragraph': 'Betty Figueroa, 52, rides the 720 Wilshire rapid bus for more than two hours every morning from her apartment in the Koreatown neighborhood of Los Angeles to her housekeeping job in Brentwood. It takes her another two hours — depending on traffic — to get back to the apartment where she lives with her mother, Deborah Hernández, 80, and her two daughters each afternoon.',
#   'print_section': 'ST',
#   'print_page': '4',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-superJumbo.jpg',
#     'height': 1366,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-horizontalMediumAt2X.jpg',
#     'height': 2667,
#     'width': 4000,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-hpLarge.jpg',
#     'height': 288,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbWide-v2.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-thumbWide-v2.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoThumb-v2.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoLarge-v2.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo210-v2.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo225-v2.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo440-v2.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo252-v2.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-mediumThreeByTwo378-v2.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoLargeAt2X-v2.jpg',
#     'height': 1463,
#     'width': 2194,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoMediumAt2X-v2.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-threeByTwoSmallAt2X-v2.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine3000.jpg',
#     'height': 1688,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-watch268.jpg',
#     'height': 304,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/00THELOOK-POULTRYMECCA1-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/22/fashion/00THELOOK-POULTRYMECCA1/merlin_163972908_3cf9c0e3-f7c0-4a54-9cf0-2cc251d9ba17-mobileMasterAt3x.jpg',
#     'height': 1200,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'The Store Where Los Angeles Converges',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Los Angeles',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Families and Family Life',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Chickens', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Restaurants', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Immigration and Emigration',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Egyptian-Americans', 'rank': 5, 'major': 'N'},
#    {'name': 'subject', 'value': 'Korean-Americans', 'rank': 6, 'major': 'N'},
#    {'name': 'subject', 'value': 'Hispanic-Americans', 'rank': 7, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Halal Foods and Products',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Al Salam Polleria (Los Angeles)',
#     'rank': 9,
#     'major': 'N'}],
#   'pub_date': '2019-12-21T11:00:17+0000',
#   'document_type': 'article',
#   'news_desk': 'Styles',
#   'section_name': 'Style',
#   'byline': {'original': 'By Jake Michaels and Walter Thompson-Hernández',
#    'person': [{'firstname': 'Jake',
#      'middlename': None,
#      'lastname': 'Michaels',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Walter',
#      'middlename': None,
#      'lastname': 'Thompson-Hernández',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490',
#   'word_count': 1919,
#   'uri': 'nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490'},
#  {'abstract': 'As she finishes her first year as our California restaurant critic, Tejal Rao names the flavors she can’t forget from in and around the city.',
#   'web_url': 'https://www.nytimes.com/2019/12/09/dining/best-food-in-los-angeles.html',
#   'snippet': 'As she finishes her first year as our California restaurant critic, Tejal Rao names the flavors she can’t forget from in and around the city.',
#   'lead_paragraph': 'LOS ANGELES — Throughout my first year as a restaurant critic living in Los Angeles, zigzagging across the city in my car, I kept a running list of delicious things I wanted to tell you about. ',
#   'print_section': 'D',
#   'print_page': '11',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-horizontalMediumAt2X.jpg',
#     'height': 2333,
#     'width': 3500,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbWide-v2.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-thumbWide-v2.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoThumb-v2.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoLarge-v2.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo210-v2.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo225-v2.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo440-v2.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo252-v2.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-mediumThreeByTwo378-v2.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-threeByTwoLargeAt2X-v2.jpg',
#     'height': 1986,
#     'width': 2980,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-threeByTwoMediumAt2X-v2.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-threeByTwoSmallAt2X-v2.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/merlin_162819633_8f9555be-eeef-4cee-9cdc-258cd8411beb-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/11/dining/09best-LA-dish10/09best-LA-dish10-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
# ...
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoLargeAt2X.jpg',
#     'height': 2000,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-articleInline.jpg',
#     'height': 143,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-hpSmall.jpg',
#     'height': 122,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-blogSmallInline.jpg',
#     'height': 113,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mediumFlexible177.jpg',
#     'height': 133,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine3000.jpg',
#     'height': 1688,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2019/12/31/realestate/31LOCATION-STUDIO-CITY-slide-7VC3/31LOCATION-STUDIO-CITY-slide-7VC3-mobileMasterAt3x.jpg',
#     'height': 1350,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'Where Does the House End and the Yard Begin?',
#    'kicker': 'On Location',
#    'content_kicker': None,
#    'print_headline': 'This Private Urban Oasis Lets the Outside In',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Real Estate and Housing (Residential)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Home Repairs and Improvements',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Los Angeles (Calif)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Restoration and Renovation',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Interior Design and Furnishings',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Furniture', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Studio City (Los Angeles, Calif)',
#     'rank': 7,
#     'major': 'N'}],
#   'pub_date': '2019-12-31T10:01:27+0000',
#   'document_type': 'article',
#   'news_desk': 'RealEstate',
#   'section_name': 'Real Estate',
#   'byline': {'original': 'By Tim McKeough',
#    'person': [{'firstname': 'Tim',
#      'middlename': None,
#      'lastname': 'McKeough',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/100c5fa3-3753-51aa-ab57-33e6c86ede74',
#   'word_count': 823,
#   'uri': 'nyt://article/100c5fa3-3753-51aa-ab57-33e6c86ede74'}]

# %% [markdown]
# Assign the list of articles to a variable that will be later used to loop through

# %%
articles = decoded_articles_request_text['response']['docs']

# %% [markdown]
# Confirm the type of variable for the list of articles variable

# %%
type(articles)
# Out:
# list

# %% [markdown]
# - Create a dictionary to hold the article details. Initialize the dictionary values to an empty list for each key.
#
#
# - Loop through the articles
#     - Assign the JSON values you will eventually store in a table to a variable
#     - Convert the pub_date to a [datetime format](https://www.geeksforgeeks.org/python-pandas-to_datetime/)
#     - Append the variable to the appropriate key for the dictionary initialized above
#     - Print out the variable value
#     - To delimit each article, print out a line of repeating non-alphanumeric characters of your choice

# %%
nyt_article_data = {
    '_id':[], 
    'web_url':[],
    'main':[],
    'document_type':[],
    'pub_date':[],
    'word_count':[],
    'type_of_material':[]
}

for article in articles:
    _id = article['_id']
    nyt_article_data['_id'].append(_id)
    print (_id)
    
    web_url = article['web_url']
    nyt_article_data['web_url'].append(web_url)
    print (web_url)
    
    main = article['headline']['main']
    nyt_article_data['main'].append(main)
    print (main)
    
    document_type = article['document_type']
    nyt_article_data['document_type'].append(document_type)
    print (document_type)
    
    pub_date = article['pub_date']
    datetime.strptime(pub_date, '%Y-%m-%dT%H:%M:%S%z')
    nyt_article_data['pub_date'].append(pub_date)
    print (pub_date)
    
    word_count = article['word_count']
    nyt_article_data['word_count'].append(word_count)
    print (word_count)
    
    type_of_material = article['type_of_material']
    nyt_article_data['type_of_material'].append(type_of_material)
    print (type_of_material)
    
    print('*****************************')
# Out:
# nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490
# https://www.nytimes.com/2019/12/21/style/la-fresh-poultry-immigrant-family-recipes.html
# The Store Where Los Angeles Converges
# article
# 2019-12-21T11:00:17+0000
# 1919
# News
# *****************************
# nyt://article/472d5f81-6179-568a-abca-26d218c3cb6f
# https://www.nytimes.com/2019/12/09/dining/best-food-in-los-angeles.html
# The 10 Best Los Angeles Dishes of 2019
# article
# 2019-12-09T16:41:45+0000
# 1291
# News
# *****************************
# nyt://article/21cf7105-227f-58d1-a004-7cab86ea11dc
# https://www.nytimes.com/2019/12/20/books/review/new-paperbacks.html
# New in Paperback: ‘Dear Los Angeles’ and ‘The Fifth Risk.’
# article
20/books/review/new-paperbacks.html', 'https://www.nytimes.com/2019/12/24/realestate/playa-del-rey-los-angeles-civic-pride-soars-in-this-tiny-beach-community.html', 'https://www.nytimes.com/2019/12/18/opinion/los-angeles-debate.html', 'https://www.nytimes.com/2019/12/16/sports/basketball/lebron-james-lakers-road-wins-record.html', 'https://www.nytimes.com/2019/12/16/business/fashion-nova-underpaid-workers.html', 'https://www.nytimes.com/2019/12/01/us/los-angeles-shade-climate-change.html', 'https://www.nytimes.com/interactive/2019/12/22/us/los-angeles-homeless-black-residents.html', 'https://www.nytimes.com/2019/12/31/realestate/where-does-the-house-end-and-the-yard-begin.html'], 'main': ['The Store Where Los Angeles Converges', 'The 10 Best Los Angeles Dishes of 2019', 'New in Paperback: ‘Dear Los Angeles’ and ‘The Fifth Risk.’', 'Playa del Rey, Los Angeles: Civic Pride Soars in This Tiny Beach Community', 'Which Candidate Will Star in Hollywood’s Democratic Debate?', 'Lakers and LeBron James Can Tie Road Wins Record This Week', 'Fashion Nova’s Secret: Underpaid Workers in Los Angeles Factories', '‘Turn Off the Sunshine’: Why Shade Is a Mark of Privilege in Los Angeles', 'Black, Homeless and Burdened by L.A.’s Legacy of Racism', 'Where Does the House End and the Yard Begin?'], 'document_type': ['article', 'article', 'article', 'article', 'article', 'article', 'article', 'article', 'multimedia', 'article'], 'pub_date': ['2019-12-21T11:00:17+0000', '2019-12-09T16:41:45+0000', '2019-12-20T10:00:04+0000', '2019-12-24T14:07:21+0000', '2019-12-19T00:04:33+0000', '2019-12-16T18:14:37+0000', '2019-12-16T10:00:18+0000', '2019-12-01T23:26:05+0000', '2019-12-23T00:55:05+0000', '2019-12-31T10:01:27+0000'], 'word_count': [1919, 1291, 377, 1496, 1287, 599, 2397, 1411, 0, 823], 'type_of_material': ['News', 'News', 'List', 'News', 'Op-Ed', 'News', 'News', 'News', 'Interactive Feature', 'News']}

# %% [markdown]
# Assign the article details dictionary to a dataframe

# %%
df = pd.DataFrame(nyt_article_data)
df.to_csv('NYTArticleDetailsDictionary.csv', index=False)

# %% [markdown]
# Print out the first 5 rows of the dataframe

# %%
df.head(5)
# Out:
#                                                  _id  \
# 0  nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207...
# 1  nyt://article/472d5f81-6179-568a-abca-26d218c3...
# 2  nyt://article/21cf7105-227f-58d1-a004-7cab86ea...
# 3  nyt://article/796d9524-d1b1-5dc0-a2fd-13c5af9f...
# 4  nyt://article/124d9577-f58d-5da7-b6e6-d06fb3f5...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2019/12/21/style/la-fr...
# 1  https://www.nytimes.com/2019/12/09/dining/best...
# 2  https://www.nytimes.com/2019/12/20/books/revie...
# 3  https://www.nytimes.com/2019/12/24/realestate/...
# 4  https://www.nytimes.com/2019/12/18/opinion/los...
#
#                                                 main document_type  \
# 0              The Store Where Los Angeles Converges       article
# 1             The 10 Best Los Angeles Dishes of 2019       article
# 2  New in Paperback: ‘Dear Los Angeles’ and ‘The ...       article
# 3  Playa del Rey, Los Angeles: Civic Pride Soars ...       article
# 4  Which Candidate Will Star in Hollywood’s Democ...       article
#
#                    pub_date  word_count type_of_material
# 0  2019-12-21T11:00:17+0000        1919             News
# 1  2019-12-09T16:41:45+0000        1291             News
# 2  2019-12-20T10:00:04+0000         377             List
# 3  2019-12-24T14:07:21+0000        1496             News
# 4  2019-12-19T00:04:33+0000        1287            Op-Ed

# %% [markdown]
# Establish a connection to your assignment_02 database.
#
# Append ?charset=utf8 to the database name to avoide codec errors.

# %%
engine = create_engine('mysql+mysqldb://lindseyf_dba:sql_2020@lindseyfry.lmu.build/lindseyf_assignment_02?charset=utf8')

# %% [markdown]
# Insert the dataframe contents to the nyt_article table you previously created.
#
# Ensure your variables in the articles for loop matches the table's column names.
#
# Set the if_exists argument to append to insert into the table you already created.
#
# Do not insert the dataframe's index column.

# %%
df.to_sql('nyt_article', con = engine, if_exists='append', index = False)

# %% [markdown]
# ---

# %% [markdown]
# ### Clear out the nyt_article table before proceeding.
# Run the following SQL in phpMyAdmin or TablePlus:
#
# TRUNCATE TABLE nyt_article;

# %% [markdown]
# ---

# %% [markdown]
# ### Make 10 requests to the API to collect 100 articles and save the results to the nyt_article table
# A single API requests only returns 10 articles. Use the page parameter to "paginate" through the results.
#
# The range function returns a range of numbers. range(10) returns 0-9.
#
# Replace the placeholders denoted by \~ALL_CAPS\~.

# %%
for page in range(10):
    print('Page:', page)
        
    api_url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    params = {'api-key':'sgBFDFyjvlJyF1xsAcUDZUQV2neZzQ1r', 'page':page, 'begin_date':'20190101', 'end_date':'20191231', 'q':'Los Angeles'}

    articles_request = requests.get(api_url, params=params)

    decoded_articles_request_text = json.loads(articles_request.text)

    articles = decoded_articles_request_text['response']['docs']

    nyt_article_data = {
    '_id':[], 
    'web_url':[],
    'main':[],
    'document_type':[],
    'pub_date':[],
    'word_count':[],
    'type_of_material':[]
    }

    for article in articles:
        _id = article['_id']
        nyt_article_data['_id'].append(_id)
        print (_id)

        web_url = article['web_url']
        nyt_article_data['web_url'].append(web_url)
        print (web_url)

        main = article['headline']['main']
        nyt_article_data['main'].append(main)
        print (main)

        document_type = article['document_type']
        nyt_article_data['document_type'].append(document_type)
        print (document_type)

        pub_date = article['pub_date']
        datetime.strptime(pub_date, '%Y-%m-%dT%H:%M:%S%z')
        nyt_article_data['pub_date'].append(pub_date)
        print (pub_date)

        word_count = article['word_count']
        nyt_article_data['word_count'].append(word_count)
        print (word_count)

        type_of_material = article['type_of_material']
        nyt_article_data['type_of_material'].append(type_of_material)
        print (type_of_material)

        print('*****************************')
        
    df = pd.DataFrame(nyt_article_data)
    df.to_csv('NYTArticleDetailsDictionary.csv', index=False)
    
    df.to_sql('nyt_article', con = engine, if_exists='append', index = False)
# Out:
# Page: 0
# nyt://article/285b7552-6a8e-53a7-9c1c-ee5bd207f490
# https://www.nytimes.com/2019/12/21/style/la-fresh-poultry-immigrant-family-recipes.html
# The Store Where Los Angeles Converges
# article
# 2019-12-21T11:00:17+0000
# 1919
# News
# *****************************
# https://www.nytimes.com/2019/10/31/sports/baseball/ron-fairly-dead.html
# Ron Fairly, Dodger Star Turned Broadcaster, Dies at 81
# article
# 2019-10-31T21:00:57+0000
# 746
# Obituary (Obit)
# *****************************
# Page: 9
# nyt://article/f0eb431b-37fa-57b3-8b15-2826639ef17d
# https://www.nytimes.com/2019/11/01/business/sqirl-jessica-koslow-work-diary.html
# The Work Diary of the Genius of Jam, Sqirl’s Jessica Koslow
# article
# 2019-11-01T09:00:14+0000
# 1939
# News
# *****************************
# nyt://article/3a480126-293d-53ec-b4d6-9c6773d5e697
# https://www.nytimes.com/2019/11/01/sports/kawhi-leonard-clippers-spurs.html
# A Little Tension, a Little Nostalgia: Kawhi Leonard Faces the Spurs
# article
# 2019-11-01T11:38:59+0000
# 979
# News
# *****************************
# nyt://article/a19fb1cd-4ac6-5145-9d02-d24f4a450656
# https://www.nytimes.com/2019/10/30/us/getty-fire-california-kincade.html
# Fires Threaten Reagan Library and Getty Museum
# article
# 2019-10-30T12:57:58+0000
# 2004
# News
# *****************************
# nyt://article/d2b31258-00f4-5dc8-9abc-cdf5b29f9cef
# https://www.nytimes.com/2019/10/31/us/california-fire.html
# Homes Burn in San Bernardino as California Battles Wildfires
# article
# 2019-10-31T12:14:49+0000
# 2223
# News
# *****************************
# nyt://article/46dce59e-2f97-5bf6-9afb-b38997086d56
# https://www.nytimes.com/2019/10/28/us/getty-kincade-fires-california.html
# With California Ablaze, Firefighters Strain to Keep Up
# article
# 2019-10-28T23:58:00+0000
# 1385
# News
# *****************************
# nyt://video/92a1c714-9fc9-5222-b755-0aafe521d582
# https://www.nytimes.com/video/us/100000006797674/california-fires-simi-valley.html
# Southern California Fire Danger Intensifies With Powerful Winds
# multimedia
# 2019-10-30T15:37:46+0000
# 0
# Video
# *****************************
# nyt://article/9a97660f-190e-5d9a-8422-903a6e490ac0
# https://www.nytimes.com/2019/10/17/arts/music/ojai-festival-los-angeles-philharmonic-ara-guzelimian.html
# Ojai Feels the Aftershock of Los Angeles Philharmonic Upheaval
# article
# 2019-10-17T13:00:08+0000
# 484
# News
# *****************************
# nyt://video/ba0fd3d5-0bd2-5239-bebc-ca51bfb906bd
# https://www.nytimes.com/video/us/100000006792866/wildfires-california.html
# Firefighters Race to Contain Blazes Across State
# multimedia
# 2019-10-28T17:35:05+0000
# 0
# Video
# *****************************
# nyt://article/cc5f38fb-f9fd-5ffb-a689-5ae496429c0e
# https://www.nytimes.com/2019/10/26/style/private-firefighters-california.html
# While California Fires Rage, the Rich Hire Private Firefighters
# article
# 2019-10-26T09:00:08+0000
# 1497
# News
# *****************************
# nyt://article/acc52074-ae87-5d91-8ab7-9486e320b86d
# https://www.nytimes.com/2019/10/25/business/lime-bird-scooters-rechargers.html
# In the Van With the ‘Juicers’ Who Round Up and Recharge Lime Scooters
# article
# 2019-10-25T16:24:28+0000
# 1253
# News
# *****************************

# %% [markdown]
# Confirm 100 articles were properly inserted into the nyt_article table. No need to provide proof. I will be running a SELECT on the table.
