# %% [markdown]
# Import the necessary libraries
# - To make a web page request
# - To save data to a dataframe
# - To interact with an SQL database
# - To parse web pages

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# ### Web scrape a single web page and save the results to the simplyhired_job table

# %% [markdown]
# Set a variable to store the web page URL

# %%
url = 'https://www.simplyhired.com'

# %% [markdown]
# Set a dict of parameters to pass to the URL

# %%
params=dict(query='web scraping')

# %% [markdown]
# Make a GET request with the defined URL and the dict of parameters

# %%
extended_request = requests.get(url, params=dict(q='SQL'))

# %% [markdown]
# Confirm the GET request received a 200 HTTP status code

# %%
extended_request
# Out:
# <Response [200]>

# %% [markdown]
# View the text in the GET request result

# %%
extended_request.text
# Out:
# '<!DOCTYPE html><html data-css="home_redesign" lang="en"  ><head ga-id="UA-1039096-6"><meta name="viewport" content="width=device-width, minimum-scale=1, initial-scale=1"><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><title>Job Search Engine | SimplyHired</title><meta name="description" content="Search for job opportunities across the United States on SimplyHired. Browse by job category, city, state, employer and more. Get a head start and post your resume." /><meta name="keywords" content="job search engine, jobs, job listings, find jobs, careers, employment opportunity, online job sites, resumes, salaries, simple, hire" /><link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" /><link rel="apple-touch-icon" href="/apple-touch-icon.png" /><link rel="canonical" href="https://www.simplyhired.com/" /><meta name="robots" content="noodp,noydir" /><link rel="alternate" hreflang="ru-ru" href="https://www.simplyhired.ru/" /><link rel="alternate" hreflang="fr-be" href="https://www.simplyhired.be/" /><link rel="alternate" hreflang="fr-fr" href="https://www.simplyhired.fr/" /><link rel="alternate" hreflang="sv-se" href="https://www.simplyhired.se/" /><link rel="alternate" hreflang="es-es" href="https://www.simplyhired.es/" /><link rel="alternate" hreflang="nl-be" href="https://www.simplyhired.be/" /><link rel="alternate" hreflang="en-gb" href="https://www.simplyhired.co.uk" /><link rel="alternate" hreflang="x-default" href="https://www.simplyhired.com" /><link rel="alternate" hreflang="zh-cn" href="https://www.simplyhired.cn/" /><link rel="alternate" hreflang="es-ar" href="https://www.simplyhired.com.ar/" /><link rel="alternate" hreflang="ko-kr" href="https://www.simplyhired.kr/" /><link rel="alternate" hreflang="es-mx" href="https://www.simplyhired.mx" /><link rel="alternate" hreflang="nl-nl" href="https://www.simplyhired.nl/" /><link rel="alternate" hreflang="en-au" href="https://www.simplyhired.com.au" /><link rel="alternate" hreflang="de-de" href="https://www.simplyhired.de/" /><link rel="alternate" hreflang="fr-ch" href="https://fr.simplyhired.ch/" /><link rel="alternate" hreflang="en-in" href="https://www.simplyhired.co.in" /><link rel="alternate" hreflang="it-ch" href="https://it.simplyhired.ch/" /><link rel="alternate" hreflang="fr-ca" href="https://fr.simplyhired.ca" /><link rel="alternate" hreflang="en-ie" href="https://www.simplyhired.ie/" /><link rel="alternate" hreflang="it-it" href="https://www.simplyhired.it/" /><link rel="alternate" hreflang="ja-jp" href="https://www.simplyhired.jp/" /><link rel="alternate" hreflang="en-ca" href="https://www.simplyhired.ca" /><link rel="alternate" hreflang="pt-pt" href="https://www.simplyhired.pt/" /><link rel="alternate" hreflang="de-ch" href="https://www.simplyhired.ch/" /><link rel="alternate" hreflang="en-za" href="https://za.simplyhired.com" /><link rel="alternate" hreflang="de-at" href="https://www.simplyhired.at/" /><link rel="alternate" hreflang="pt-br" href="https://www.simplyhired.com.br/" /><link href="https://plus.google.com/100239036095536335585" rel="publisher"><link rel=\'stylesheet\' href=\'//fonts.googleapis.com/css?family=Source+Sans+Pro:200,300,400,600,700,900\'><link rel="stylesheet" href="/packed/6fa90e2d3c65c4ce93a8/main.css"/><script async src="/packed/c505496edc2fa67cde40/main.js"></script><meta id=\'sentry-json\' data-json=\'{&quot;init&quot;:{&quot;dsn&quot;:&quot;https://f9dca67454f647c9ac710a500a0bbebb@sentry.indeed.com/2391&quot;,&quot;release&quot;:&quot;76f95bf3bb60745b53261161e781ef944e093a25&quot;,&quot;environment&quot;:&quot;PRODUCTION&quot;},&quot;user&quot;:null,&quot;ctk&quot;:null,&quot;tags&quot;:{&quot;shk&quot;:&quot;1e1vpkd2bnrbs800&quot;,&quot;login&quot;:&quot;0&quot;,&quot;site&quot;:&quot;simplyhired&quot;,&quot;appinstance&quot;:&quot;CobraDaemon&quot;},&quot;extra&quot;:null,&quot;isEnabled&quot;:true,&quot;isEnabledLocally&quot;:true}\'/></head><body id="home-page" data-csrf="3BDNKX7m96Tge-415EM4iw7mQUHLmz ...

# %% [markdown]
# Create an object of the BeautifulSoup class to parse the web page text with the html.parser parser option

# %%
soup = BeautifulSoup(extended_request.text, 'html.parser')

# %% [markdown]
# Print the BeautifulSoup object as a nicely (pretty) formatted string

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-css="home_redesign" lang="en">
#  <head ga-id="UA-1039096-6">
#   <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <title>
#     Job Search Engine | SimplyHired
#    </title>
#    <meta content="Search for job opportunities across the United States on SimplyHired. Browse by job category, city, state, employer and more. Get a head start and post your resume." name="description"/>
#    <meta content="job search engine, jobs, job listings, find jobs, careers, employment opportunity, online job sites, resumes, salaries, simple, hire" name="keywords"/>
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <link href="https://www.simplyhired.com/" rel="canonical"/>
#    <meta content="noodp,noydir" name="robots"/>
#    <link href="https://www.simplyhired.ru/" hreflang="ru-ru" rel="alternate"/>
#    <link href="https://www.simplyhired.be/" hreflang="fr-be" rel="alternate"/>
#    <link href="https://www.simplyhired.fr/" hreflang="fr-fr" rel="alternate"/>
#    <link href="https://www.simplyhired.se/" hreflang="sv-se" rel="alternate"/>
#    <link href="https://www.simplyhired.es/" hreflang="es-es" rel="alternate"/>
#    <link href="https://www.simplyhired.be/" hreflang="nl-be" rel="alternate"/>
#    <link href="https://www.simplyhired.co.uk" hreflang="en-gb" rel="alternate"/>
#    <link href="https://www.simplyhired.com" hreflang="x-default" rel="alternate"/>
#    <link href="https://www.simplyhired.cn/" hreflang="zh-cn" rel="alternate"/>
#    <link href="https://www.simplyhired.com.ar/" hreflang="es-ar" rel="alternate"/>
#    <link href="https://www.simplyhired.kr/" hreflang="ko-kr" rel="alternate"/>
#    <link href="https://www.simplyhired.mx" hreflang="es-mx" rel="alternate"/>
#    <link href="https://www.simplyhired.nl/" hreflang="nl-nl" rel="alternate"/>
#    <link href="https://www.simplyhired.com.au" hreflang="en-au" rel="alternate"/>
#    <link href="https://www.simplyhired.de/" hreflang="de-de" rel="alternate"/>
#    <link href="https://fr.simplyhired.ch/" hreflang="fr-ch" rel="alternate"/>
#    <link href="https://www.simplyhired.co.in" hreflang="en-in" rel="alternate"/>
#    <link href="https://it.simplyhired.ch/" hreflang="it-ch" rel="alternate"/>
#    <link href="https://fr.simplyhired.ca" hreflang="fr-ca" rel="alternate"/>
#    <link href="https://www.simplyhired.ie/" hreflang="en-ie" rel="alternate"/>
#    <link href="https://www.simplyhired.it/" hreflang="it-it" rel="alternate"/>
#    <link href="https://www.simplyhired.jp/" hreflang="ja-jp" rel="alternate"/>
#    <link href="https://www.simplyhired.ca" hreflang="en-ca" rel="alternate"/>
#    <link href="https://www.simplyhired.pt/" hreflang="pt-pt" rel="alternate"/>
#    <link href="https://www.simplyhired.ch/" hreflang="de-ch" rel="alternate"/>
#    <link href="https://za.simplyhired.com" hreflang="en-za" rel="alternate"/>
#    <link href="https://www.simplyhired.at/" hreflang="de-at" rel="alternate"/>
#    <link href="https://www.simplyhired.com.br/" hreflang="pt-br" rel="alternate"/>
#    <link href="https://plus.google.com/100239036095536335585" rel="publisher"/>
#    <link href="//fonts.googleapis.com/css?family=Source+Sans+Pro:200,300,400,600,700,900" rel="stylesheet"/>
#    <link href="/packed/6fa90e2d3c65c4ce93a8/main.css" rel="stylesheet">
#     <script async="" src="/packed/c505496edc2fa67cde40/main.js">
#     </script>
#     <meta data-json='{"init":{"dsn":"https://f9dca67454f647c9ac710a500a0bbebb@sentry.indeed.com/2391","release":"76f95bf3bb60745b53261161e781ef944e093a25","environment":"PRODUCTION"},"user":null,"ctk":null,"tags":{"shk":"1e1vpkd2bnrbs800","login":"0","site":"simplyhired","appinstance":"CobraDaemon"},"extra":null,"isEnabled":true,"isEnabledLocally":true}' id="sentry-json"/>
#    </link>
#   </meta>
#  </head>
#  <body data-csrf="3BDNKX7m96Tge-415EM4iw7mQUHLmziDwJQ5WeqoQ5pUyF3kRP-zFjfHqwsSLTUHl_AzKpvzEQI9rIdB6fcamA" id="home-page">
#   <meta content="939356510115-023sd5f62vape692qqdllhnoi4qmnv0c.apps.googleusercontent.com" name="g-client-id"/>
#   <meta content="225697117996081" name="f-client-id"/>
#   <meta content="https://www.simplyhired.com/auth/facebook/login" name="f-redirect-url"/>
#   <meta content="ymBZD4pJIvenxU7e" name="i3pis-a"/>
#   <meta content="EDJxAjm7t6WArFiKmZk/f8BChlNJ/z5gYM1EkEIAZVa68rsEkxcmmg0Bo0UQvP5l+k4C8JLw8EQmZrOgmYjwIGMIFhBjfi82YiYSHyh6RmvOIc/+7/YtPDHe5v6vEP0PcUUk40hjDkmNRVtUdQ==" name="i3pis-p"/>
#   <meta content="idsync.indeed.com" name="i3pis-h"/>
#   <meta content="1e1vpkd2inrbs800" name="tk"/>
#   <div aria-hidden="true" aria-labelledby="login-heading" class="modal fade modal-login" data-keyboard="true" id="main-login-modal" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h2 class="heading" id="login-heading">
#        Sign In or Create Account
#       </h2>
#      </div>
#      <div class="modal-body">
#       <p>
#        Use Facebook or Google to sign in or register with SimplyHired.
#       </p>
#       <div class="login-buttons">
#        <button class="btn btn-facebook js-login-facebook" type="button">
#         <span>
#          Continue with Facebook
#         </span>
#        </button>
#        <button class="btn btn-google js-login-google" type="button">
#         <span>
#          Continue with Google
#         </span>
#        </button>
#       </div>
#       <p class="login-disclaimer">
#        By signing in to your account, you agree to SimplyHired's
#        <a href="/about/terms-of-service">
#         Terms of Service
#        </a>
#        and consent to our
#        <a href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy">
#         Cookie and Privacy Policy
#        </a>
#        .
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade modal-login modal-login-error" id="login-error-modal" role="dialog" tabindex="-1">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#       <span>
#        ×
#       </span>
#      </button>
#      <h4 class="modal-title">
#       ERROR
#      </h4>
#     </div>
#     <div class="modal-body">
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade modal-login modal-login-error" id="login-session-expired-modal" role="dialog" tabindex="-1">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#       <span>
#        ×
#       </span>
#      </button>
#      <h4 class="modal-title">
#       ERROR
#      </h4>
#     </div>
#     <div class="modal-body">
#     </div>
#     <div class="modal-footer">
#      <div class="btn btn-secondary js-refresh">
#       <span>
#        Refresh the Page
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <nav aria-label="Primary header" class="NavBar navbar navbar-light d-md-block d-none serp-navbar navbar-desktop top-menu NavBar-global-nav transparent-header">
#    <a class="sh-logo-link" data-event="header_logo" href="/">
#     <span class="sh-logo" title="Find Jobs and Careers - SimplyHired.com Job Search">
#     </span>
#    </a>
#    <div class="navbar-filler">
#    </div>
#    <ul class="nav navbar-nav">
#     <li class="nav-item hidden-sm-down">
#      <a class="nav-link" href="/post-jobs-free">
#       <div class="post-job-free-btn">
#        <i aria-hidden="true" class="fas fa-briefcase">
#        </i>
#        <span>
#         Post Jobs
#        </span>
#       </div>
#      </a>
#     </li>
#     <li class="nav-item login-desktop-nav-item">
#      <button class="nav-login-menu-button" type="button">
#       Sign In
#       <i class="button-toggle-angle fas fa-angle-down">
#       </i>
#      </button>
#      <ul class="nav-login-menu">
#       <li class="nav-login-menu-item">
#        <button aria-expanded="false" class="nav-login-menu-link" id="nav-login-modal-trigger">
#         Job Seeker
#        </button>
#       </li>
#       <li class="nav-login-menu-item">
#        <a class="nav-login-menu-link" href="https://employer.simplyhired.com" target="_self">
#         Employer ATS
#        </a>
#       </li>
#       <li class="nav-login-menu-item">
#        <a class="nav-login-menu-link" href="https://hr.simplyhired.com" target="_self">
#         Human Resources
#        </a>
#       </li>
#      </ul>
#     </li>
#     <li class="nav-item">
#      <button aria-controls="slideout-menu" aria-expanded="false" aria-label="Main menu" class="btn js-hamburger hamburger" data-toggle="collapse">
#       <i class="fas fa-bars">
#       </i>
#      </button>
#      <nav class="slideout-menu-container">
#       <nav aria-hidden="true" aria-label="Main menu" class="slideout-menu js-menu" id="slideout-menu">
#        <span aria-label="Top of menu" classname="menu-catchFocusOut" tabindex="0">
#        </span>
#        <div class="slideout-menu-content">
#         <div class="section-header search-section js-section-header">
#          <button aria-label="Close menu" class="btn close-icon js-close">
#          </button>
#         </div>
#         <div class="section-header js-section-header">
#          <button aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-signin" data-toggle="collapse" type="button">
#           Sign In
#           <i class="section-toggle-angle fas fa-angle-down">
#           </i>
#          </button>
#         </div>
#         <div aria-controls="js-signin" aria-expanded="false" class="section-body js-section-body collapse js-signin">
#          <ul>
#           <li>
#            <button class="btn section-option" id="mobile-login-modal-trigger">
#             Job Seeker
#            </button>
#           </li>
#           <li>
#            <a href="https://employer.simplyhired.com/">
#             Employer ATS
#            </a>
#           </li>
#           <li>
#            <a href="https://hr.simplyhired.com/">
#             Human Resources
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="slideout-menu-divider js-search-divider">
#         </div>
#         <div class="section-header">
#          <span class="section-toggle">
#           <a href="/post-jobs-free">
#            Post Jobs Free
#           </a>
#          </span>
#         </div>
#         <div class="section-header">
#          <span class="section-toggle">
#           <a href="https://simplyhired.com/hris">
#            Human Resources
#           </a>
#          </span>
#         </div>
#         <div class="section-header NavBar-sectionResumeBuilder">
#          <span class="section-toggle">
#           <a href="/resumebuilder" target="_blank">
#            Resume Builder
#           </a>
#          </span>
#         </div>
#         <div class="section-header">
#          <span class="section-toggle">
#           <a href="/companies">
#            Company Pages
#           </a>
#          </span>
#         </div>
#         <div class="section-header js-section-header">
#          <button aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-jobseekers" data-toggle="collapse">
#           Job Tools
#           <i class="section-toggle-angle fas fa-angle-down">
#           </i>
#          </button>
#         </div>
#         <div aria-controls="js-jobseekers" aria-expanded="false" class="section-body js-section-body collapse js-jobseekers">
#          <ul>
#           <li>
#            <a class="local" href="/local-jobs">
#             Local Jobs
#            </a>
#           </li>
#           <li>
#            <a class="salary" href="/salaries">
#             Salary Estimator
#            </a>
#           </li>
#           <li>
#            <a class="career" href="/guide/career">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a class="resumes" href="/guide/resume">
#             Resumes
#            </a>
#           </li>
#           <li>
#            <a class="coverletter" href="/guide/cover-letter">
#             Cover Letters
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="section-header">
#          <span class="section-toggle">
#           <a href="/about/contact-us" rel="nofollow" target="_self">
#            Contact Us
#           </a>
#          </span>
#         </div>
#         <div class="menu-footer">
#          <div class="copyright">
#           <span class="sh-logo">
#           </span>
#           <br/>
#           <div class="dropup international-dropdown international-dropdown-v2 hidden-sm-down">
#            <button aria-expanded="false" aria-haspopup="true" class="international-dropdown-button-v2" data-toggle="dropdown" type="button">
#             <span>
#              United States
#             </span>
#             <div class="dropdown-arrow-container">
#              <i class="fas fa-angle-down">
#              </i>
#             </div>
#            </button>
#            <div class="dropdown-menu international-dropdown-wrapper">
#             <div class="international-dropdown-list">
#              <a class="current-country dropdown-item" href="https://www.simplyhired.com">
#               United States
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.ca">
#               Canada
#              </a>
#              <div class="dropdown-divider">
#              </div>
#              <a class="dropdown-item" href="https://www.simplyhired.com.ar">
#               Argentina
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.com.au">
#               Australia
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.be">
#               België
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.com.br">
#               Brasil
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.de">
#               Deutschland
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.es">
#               España
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.fr">
#               France
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.co.in">
#               India
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.ie">
#               Ireland
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.it">
#               Italia
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.mx">
#               México
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.nl">
#               Nederland
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.at">
#               Österreich
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.pt">
#               Portugal
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.ch">
#               Schweiz
#              </a>
#              <a class="dropdown-item" href="https://za.simplyhired.com">
#               South Africa
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.se">
#               Sverige
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.co.uk">
#               United Kingdom
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.ru">
#               Россия
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.kr">
#               한국
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.cn">
#               中国
#              </a>
#              <a class="dropdown-item" href="https://www.simplyhired.jp">
#               日本
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="misc-links text-xs-left">
#            © 2020 SH Inc. |
#            <a href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy">
#             Privacy
#            </a>
#            |
#            <a href="/about/terms-of-service">
#             Terms
#            </a>
#            <br/>
#            |
#            <a href="https://hrtechprivacy.com/">
#             Privacy Center
#            </a>
#            <br/>
#            |
#            <a href="/about/ccpa">
#             Do Not Sell My Personal Information
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <span aria-label="Bottom of menu" classname="menu-catchFocusOut" tabindex="0">
#        </span>
#       </nav>
#      </nav>
#     </li>
#    </ul>
#   </nav>
#  </body>
# </html>
# <div class="home-content">
#  <div class="home-wrap">
#   <div data-react-class="Homepage" data-react-props='{"country":"US","autofillLocation":"Los Angeles, CA","formattedSponsored":null,"homepageTranslations":"{\"\":{\"Plural-Forms\":\" nplurals=2; plural=n != 1;\",\"Content-Type\":\" text/plain; charset=UTF-8\"}}","recentQueries":[],"isRenderedClientSide":false,"isMobile":false}' data-reactroot="">
#    <div class="Homepage-wrapper">
#     <div class="HomepageSearchBar-homeBanner">
#      <div class="HomepageSearchBar-bannerContainer">
#       <div class="HomepageSearchBar-title">
#        One Search, Millions of Jobs
#       </div>
#       <form action="/search" method="get">
#        <div class="HomepageSearchBar-searchContainer">
#         <input name="from" type="hidden" value="homepage_searchbox"/>
#         <div class="HomepageSearchBar-searchInputTitle">
#          Job Title, Skills or Company
#         </div>
#         <input autocomplete="off" class="HomepageSearchBar-searchInput id_f_keywords ui-autocomplete-input" name="q" placeholder="Job Title, Skills or Company" type="text"/>
#         <div class="HomepageSearchBar-searchLocationInputTitle">
#          Location
#         </div>
#         <input autocomplete="off" class="HomepageSearchBar-searchLocationInput id_f_location ui-autocomplete-input" name="l" placeholder="City, State or ZIP" type="text" value="Los Angeles, CA"/>
#         <button class="HomepageSearchBar-searchSubmitButton" data-event="home_page_search_jobs" type="submit">
#          <span class="HomepageSearchBar-searchSubmitText">
#           Search Jobs
#          </span>
#          <div class="HomepageSearchBar-searchSubmitIcon">
#          </div>
#         </button>
#        </div>
#       </form>
#       <div class="HomepageSearchBar-resumeLine">
#        <span class="HomepageSearchBar-resumeMobile">
#         <a class="HomepageSearchBar-link" href="/profile" target="_blank">
#          Upload
#         </a>
#         a resume to easily apply to jobs.
#        </span>
#        <span class="HomepageSearchBar-resumeDesktop">
#         <a class="HomepageSearchBar-link" href="/profile" target="_blank">
#          Upload
#         </a>
#         or
#         <a class="HomepageSearchBar-link" href="/resumebuilder" target="_blank">
#          create a resume
#         </a>
#         to easily apply to jobs.
#        </span>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div class="HomepageSerp-tabBar">
#       <div class="HomepageSerp-tab is-active">
#        <div class="HomepageSerp-tabTitle">
#         Jobs near you
#        </div>
#        <div class="HomepageSerp-tabDescription">
#         Jobs posted in the last week
#        </div>
#       </div>
#       <div class="HomepageSerp-tabSpacer">
#       </div>
#      </div>
#      <div class="HomepageSerp-content">
#       <div class="HomepageSerp-leftPane">
#        <div class="HomepageSerp-fadeIn" style="opacity:0">
#        </div>
#       </div>
#       <div class="HomepageSerp-rightPane RightPane">
#        <div class="HomepageSerp-fadeIn" style="opacity:0">
#         <div class="closerow RightPane-closeRow HomepageSerp-rightPaneCloseButton">
#          <span class="closebutton RightPane-closeButton">
#           <span>
#            <i class="fas fa-arrow-left">
#            </i>
#            Return to results
#           </span>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="HomepageResumeBuilderBanner-container">
#      <div class="HomepageResumeBuilderBanner-imageDesktopWrapper">
#       <div class="HomepageResumeBuilderBanner-imageDesktopBackground">
#       </div>
#       <div class="HomepageResumeBuilderBanner-imageDesktop">
#       </div>
#      </div>
#      <div class="HomepageResumeBuilderBanner-textContentDesktop">
#       <div class="HomepageResumeBuilderBanner-titleDesktop">
#        Free online resume builder
#       </div>
#       <div class="HomepageResumeBuilderBanner-descriptionDesktop">
#        Create a professional resume in minutes. Choose from a library of 30+ free resume templates and samples of career-specific writing examples.
#       </div>
#       <a href="/resumebuilder">
#        <button class="HomepageResumeBuilderBanner-buttonDesktop">
#         Build your resume
#        </button>
#       </a>
#      </div>
#      <div class="HomepageResumeBuilderBanner-imageMobileWrapper">
#       <div class="HomepageResumeBuilderBanner-imageMobile">
#       </div>
#      </div>
#      <div class="HomepageResumeBuilderBanner-textContentMobile">
#       <div class="HomepageResumeBuilderBanner-titleMobile">
#        Applying made easy
#       </div>
#       <div class="HomepageResumeBuilderBanner-descriptionMobile">
#        Upload your resume to your SimplyHired profile to easily apply for jobs using Simply Apply
#       </div>
#       <a href="/profile">
#        <button class="HomepageResumeBuilderBanner-buttonMobile">
#         Upload your resume
#        </button>
#       </a>
#      </div>
#     </div>
#     <div class="HomepageTopTrendingFooter-container">
#      <div class="HomepageTopTrendingFooter-topContent">
#       <div class="HomepageTopTrendingFooter-title">
#        Browse SimplyHired
#       </div>
#       <div class="HomepageTopTrendingFooter-description">
#        Browse SimplyHired for jobs, view local and national salary information, discover companies, and learn about the job market in a specific city.
#       </div>
#      </div>
#      <div class="HomepageTopTrendingFooter-mainContent">
#       <div class="HomepageTopTrendingFooter-topTrending">
#        <div class="HomepageTopTrendingFooter-topTrendingSection">
#         <div class="HomepageTopTrendingFooter-topTrendingSectionTitle">
#          Jobs
#         </div>
#         <div class="HomepageTopTrendingFooter-topTrendingSectionContent">
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Part%20Time%20Jobs&amp;l=">
#           Part Time Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Full%20Time%20jobs&amp;l=">
#           Full Time jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Accounting%20Jobs&amp;l=">
#           Accounting Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Teen%20Jobs&amp;l=">
#           Teen Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Summer%20Jobs&amp;l=">
#           Summer Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Work%20From%20Home%20Jobs&amp;l=">
#           Work From Home Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Human%20Resources%20Jobs&amp;l=">
#           Human Resources Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Nursing%20Jobs&amp;l=">
#           Nursing Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Administrative%20Assistant%20Jobs&amp;l=">
#           Administrative Assistant Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Warehouse%20Jobs&amp;l=">
#           Warehouse Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Receptionist%20Jobs&amp;l=">
#           Receptionist Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Sales%20Jobs&amp;l=">
#           Sales Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Retail%20Jobs&amp;l=">
#           Retail Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Marketing%20Jobs&amp;l=">
#           Marketing Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Customer%20Service%20Jobs&amp;l=">
#           Customer Service Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Cannabis%20Jobs&amp;l=">
#           Cannabis Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Nonprofit%20Jobs&amp;l=">
#           Nonprofit Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Social%20Worker%20Jobs&amp;l=">
#           Social Worker Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Driver%20Jobs&amp;l=">
#           Driver Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Government%20Jobs&amp;l=">
#           Government Jobs
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/browse-jobs/titles">
#           Browse All Jobs
#          </a>
#         </div>
#        </div>
#        <div class="HomepageTopTrendingFooter-topTrendingSection">
#         <div class="HomepageTopTrendingFooter-topTrendingSectionTitle">
#          Cities
#         </div>
#         <div class="HomepageTopTrendingFooter-topTrendingSectionContent">
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Atlanta%2C%20GA">
#           Atlanta, GA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Austin%2C%20TX">
#           Austin, TX
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Boston%2C%20MA">
#           Boston, MA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Charlotte%2C%20NC">
#           Charlotte, NC
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Chicago%2C%20IL">
#           Chicago, IL
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Dallas%2C%20TX">
#           Dallas, TX
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Denver%2C%20CO">
#           Denver, CO
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Houston%2C%20TX">
#           Houston, TX
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Las%20Vegas%2C%20NV">
#           Las Vegas, NV
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Los%20Angeles%2C%20CA">
#           Los Angeles, CA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Miami%2C%20FL">
#           Miami, FL
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=New%20York%2C%20NY">
#           New York, NY
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Orlando%2C%20FL">
#           Orlando, FL
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Philadelphia%2C%20PA">
#           Philadelphia, PA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Phoenix%2C%20AZ">
#           Phoenix, AZ
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=San%20Antonio%2C%20TX">
#           San Antonio, TX
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=San%20Diego%2C%20CA">
#           San Diego, CA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Seattle%2C%20WA">
#           Seattle, WA
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Tampa%2C%20FL">
#           Tampa, FL
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=&amp;l=Washington%2C%20DC">
#           Washington, DC
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/browse-jobs/cities">
#           Browse All Cities
#          </a>
#         </div>
#        </div>
#        <div class="HomepageTopTrendingFooter-topTrendingSection">
#         <div class="HomepageTopTrendingFooter-topTrendingSectionTitle">
#          Companies
#         </div>
#         <div class="HomepageTopTrendingFooter-topTrendingSectionContent">
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Walmart&amp;l=">
#           Walmart
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Amazon.com&amp;l=">
#           Amazon.com
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=UPS&amp;l=">
#           UPS
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Frito-Lay&amp;l=">
#           Frito-Lay
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Kaiser%20Permanente&amp;l=">
#           Kaiser Permanente
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=The%20Home%20Depot&amp;l=">
#           The Home Depot
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Dollar%20General&amp;l=">
#           Dollar General
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Target&amp;l=">
#           Target
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Delta&amp;l=">
#           Delta
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Southwest%20Airlines&amp;l=">
#           Southwest Airlines
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Coca-Cola%20Refreshments&amp;l=">
#           Coca-Cola Refreshments
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Family%20Dollar&amp;l=">
#           Family Dollar
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Bank%20of%20America&amp;l=">
#           Bank of America
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Costco%20WholeSale&amp;l=">
#           Costco WholeSale
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Kelly%20Services&amp;l=">
#           Kelly Services
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=United%20States%20Postal%20Service&amp;l=">
#           United States Postal Service
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Starbucks&amp;l=">
#           Starbucks
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=ALDI&amp;l=">
#           ALDI
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=McDonald%27s&amp;l=">
#           McDonald's
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/search?from=homepage_trending&amp;q=Glassdoor&amp;l=">
#           Glassdoor
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/browse-jobs/companies">
#           Browse All Companies
#          </a>
#         </div>
#        </div>
#        <div class="HomepageTopTrendingFooter-topTrendingSection">
#         <div class="HomepageTopTrendingFooter-topTrendingSectionTitle">
#          Salaries
#         </div>
#         <div class="HomepageTopTrendingFooter-topTrendingSectionContent">
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Customer%20Service%20Representative%20Salaries&amp;l=">
#           Customer Service Representative Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Truck%20Driver%20Salaries&amp;l=">
#           Truck Driver Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Registered%20Nurse%20Salaries&amp;l=">
#           Registered Nurse Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Delivery%20Driver%20Salaries&amp;l=">
#           Delivery Driver Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Driver%20Salaries&amp;l=">
#           Driver Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Administrative%20Assistant%20Salaries&amp;l=">
#           Administrative Assistant Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Sales%20Representative%20Salaries&amp;l=">
#           Sales Representative Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Warehouse%20Worker%20Salaries&amp;l=">
#           Warehouse Worker Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Cashier%20Salaries&amp;l=">
#           Cashier Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Nursing%20Assistant%20Salaries&amp;l=">
#           Nursing Assistant Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Police%20Officer%20Salaries&amp;l=">
#           Police Officer Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Sales%20Associate%20Salaries&amp;l=">
#           Sales Associate Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Substitute%20Teacher%20Salaries&amp;l=">
#           Substitute Teacher Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Store%20Manager%20Salaries&amp;l=">
#           Store Manager Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Teacher%20%20Salaries&amp;l=">
#           Teacher  Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=General%20Manager%20Salaries&amp;l=">
#           General Manager Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Call%20Center%20Representative%20Salaries&amp;l=">
#           Call Center Representative Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Receptionist%20Salaries&amp;l=">
#           Receptionist Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Technician%20Salaries&amp;l=">
#           Technician Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/salaries/search?from=homepage_trending&amp;q=Retail%20Sales%20Associate%20Salaries&amp;l=">
#           Retail Sales Associate Salaries
#          </a>
#          <a class="HomepageTopTrendingFooter-sectionContentItem" href="/browse-jobs/salaries">
#           Browse All Salaries
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="HomepageTopTrendingFooter-secondaryContent">
#        <div class="HomepageTopTrendingFooter-secondaryTitle">
#         A job search tailored for you
#        </div>
#        <div class="HomepageTopTrendingFooter-secondaryDescription">
#         Find the job that's right for you.
#        </div>
#        <a href="/search?from=homepage_trending&amp;q=all%20jobs&amp;l=Los%20Angeles%2C%20CA">
#         <button class="HomepageTopTrendingFooter-secondaryButton">
#          Search Jobs
#         </button>
#        </a>
#       </div>
#      </div>
#      <div class="HomepageTopTrendingFooter-expanderContainer">
#       <i class="HomepageTopTrendingFooter-expander fas fa-angle-down">
#       </i>
#      </div>
#     </div>
#     <div class="HomepagePostJobsFreeBanner-container">
#      <div class="HomepagePostJobsFreeBanner-title">
#       Employers: Your perfect hire awaits
#      </div>
#      <div class="HomepagePostJobsFreeBanner-description">
#       Find out why over 3 million employers trust SimplyHired to deliver qualified applicants
#      </div>
#      <a class="HomepagePostJobsFreeBanner-buttonLink" href="/post-jobs-free">
#       <button class="HomepagePostJobsFreeBanner-button">
#        Post Jobs Free
#        <span class="HomepagePostJobsFreeBanner-buttonSubtext">
#         ¹
#        </span>
#       </button>
#      </a>
#      <div class="HomepagePostJobsFreeBanner-legal">
#       ¹ Free job posting offer does not apply to job sites, all staffing agencies or certain other types of jobs at SimplyHired's discretion. Terms, conditions, quality standards and usage limits apply.
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="footer-expanded redesign">
#  <div class="hybrid-container">
#   <div class="row upper-row lower-row hidden-sm-down" itemscope="" itemtype="http://schema.org/Organization">
#    <div class="footer-column col-md-3 col-xs-6">
#     <a class="footer-link" href="/" itemprop="url">
#      <img alt="Find Jobs and Careers - SimplyHired.com Job Search" class="footer-logo" itemprop="logo" src="/static/base/img/sh-logo2.png"/>
#     </a>
#     <div class="dropup international-dropdown hidden-sm-down">
#      <button aria-expanded="false" aria-haspopup="true" class="international-dropdown-button-v2" data-toggle="dropdown" type="button">
#       <span>
#        United States
#       </span>
#       <div class="dropdown-arrow-container">
#        <div class="dropdown-arrow">
#        </div>
#       </div>
#      </button>
#      <div class="dropdown-menu international-dropdown-wrapper">
#       <div class="international-dropdown-list">
#        <a class="current-country dropdown-item" href="https://www.simplyhired.com">
#         United States
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.ca">
#         Canada
#        </a>
#        <div class="dropdown-divider">
#        </div>
#        <a class="dropdown-item" href="https://www.simplyhired.com.ar">
#         Argentina
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.com.au">
#         Australia
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.be">
#         België
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.com.br">
#         Brasil
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.de">
#         Deutschland
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.es">
#         España
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.fr">
#         France
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.co.in">
#         India
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.ie">
#         Ireland
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.it">
#         Italia
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.mx">
#         México
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.nl">
#         Nederland
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.at">
#         Österreich
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.pt">
#         Portugal
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.ch">
#         Schweiz
#        </a>
#        <a class="dropdown-item" href="https://za.simplyhired.com">
#         South Africa
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.se">
#         Sverige
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.co.uk">
#         United Kingdom
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.ru">
#         Россия
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.kr">
#         한국
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.cn">
#         中国
#        </a>
#        <a class="dropdown-item" href="https://www.simplyhired.jp">
#         日本
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-column col-md-2 col-xs-6">
#     <p class="list-title">
#      Stay Connected
#     </p>
#     <ul class="footer-list-links">
#      <li>
#       <a href="/about/contact-us" rel="nofollow">
#        <span>
#         Contact Us
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="/blog/">
#        <span>
#         SimplyHired Blog
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="https://www.facebook.com/simplyhired" rel="nofollow">
#        <span>
#         Facebook
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="https://twitter.com/simplyhired" rel="nofollow">
#        <span>
#         Twitter
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="https://www.linkedin.com/company/simply-hired" rel="nofollow">
#        <span>
#         LinkedIn
#        </span>
#       </a>
#      </li>
#      <li>
#       <a href="https://www.youtube.com/user/simplyhired" rel="nofollow">
#        <span>
#         YouTube
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer-column col-md-2 col-xs-6">
#     <p class="list-title">
#      Job Tools
#     </p>
#     <ul class="footer-list-links">
#      <li>
#       <a href="/local-jobs">
#        Local Jobs
#       </a>
#      </li>
#      <li>
#       <a href="/salaries">
#        Salary Estimator
#       </a>
#      </li>
#      <li>
#       <a href="/post-jobs-free">
#        Post Jobs Free
#       </a>
#      </li>
#      <li>
#       <a href="/resumebuilder" target="_blank">
#        Resume Builder
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer-column col-md-2 col-xs-12">
#     <p class="list-title">
#      Browse
#     </p>
#     <ul class="footer-list-links">
#      <li>
#       <a href="/browse-jobs/titles">
#        All Jobs
#       </a>
#      </li>
#      <li>
#       <a href="/browse-jobs/salaries">
#        All Salaries
#       </a>
#      </li>
#      <li>
#       <a href="/browse-jobs/cities">
#        All Cities
#       </a>
#      </li>
#      <li>
#       <a href="/browse-jobs/companies">
#        All Companies
#       </a>
#      </li>
#     </ul>
#     <p class="list-title">
#      Guides
#     </p>
#     <ul class="footer-list-links">
#      <li>
#       <a href="/guide/resume">
#        Resumes
#       </a>
#      </li>
#      <li>
#       <a href="/guide/cover-letter">
#        Cover Letters
#       </a>
#      </li>
#      <li>
#       <a href="/guide/interviews">
#        Interviews
#       </a>
#      </li>
#      <li>
#       <a href="/guide/career">
#        Careers
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="footer-column col-md-3 col-xs-12 mobile-app-download">
#     <p class="list-title">
#      Take your job search wherever you go.
#     </p>
#     <ul class="footer-list-links">
#      <li>
#       <a class="apple-app-store js-gtm" data-event-action="Mobile Applications" href="https://itunes.apple.com/us/app/job-search-simply-hired/id730634951?mt=8&amp;uo=4" rel="nofollow" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="google-play-store js-gtm" data-event-action="Mobile Applications" href="https://play.google.com/store/apps/details?id=com.simplyhired.android.jobsearch" rel="nofollow" target="_blank">
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
#  <div class="base-footer">
#   <div class="hybrid-container">
#    <div class="row lower-row">
#     <div class="col-md-8 col-xs-12">
#      <div class="misc-links text-xs-center text-md-left">
#       <span>
#        © 2020 SH Inc.
#       </span>
#       |
#       <a href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy" rel="nofollow">
#        Privacy -
#        <b>
#         NEW
#        </b>
#       </a>
#       |
#       <a href="/about/terms-of-service" rel="nofollow">
#        Terms
#       </a>
#       |
#       <a href="https://hrtechprivacy.com/" rel="nofollow">
#        Privacy Center
#       </a>
#       <br/>
#       |
#       <a href="/about/ccpa" rel="nofollow">
#        Do Not Sell My Personal Information
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>

# %% [markdown]
# Open the URL in Chrome. Inspect the elements to find a pattern between the jobs.
#
# Identify the tag, attribute, and attribute value for the outermost portion of each job.
#
# Do a findAll to assign a list of jobs to a variable.

# %%
jobs = soup.find_all('div', attrs={'class':'HomepageSerp-content'})

# %% [markdown]
# Print out the variable containing the list of jobs

# %%
print(jobs)
# Out:
# [<div class="HomepageSerp-content"><div class="HomepageSerp-leftPane"><div class="HomepageSerp-fadeIn" style="opacity:0"></div></div><div class="HomepageSerp-rightPane RightPane"><div class="HomepageSerp-fadeIn" style="opacity:0"><div class="closerow RightPane-closeRow HomepageSerp-rightPaneCloseButton"><span class="closebutton RightPane-closeButton"><span><i class="fas fa-arrow-left"></i>Return to results</span></span></div></div></div></div>]

# %% [markdown]
# - Create a dictionary to hold the job details. Initialize the dictionary values to an empty list for each key.
#
#
# - Loop through the jobs
#     - Scrape for the required job components and assign each to a variable
#     - Append the variable to the appropriate key for the dictionary initialized above
#     - Print out the variable value
#     - To delimit each article, print out a line of repeating non-alphanumeric characters of your choice

# %%
for job in jobs:
    print(job)
    
    job_title = job.find('div', attrs={'class':'jobposting-title-container'})
    print('Job Title:', job_title)
    
    job_link = job.findAll('a', attrs={'rel':'nofollow'})
    print('Job Link:', job_link)
    print('*** *** *** *** *** ***')
# Out:
# <div class="HomepageSerp-content"><div class="HomepageSerp-leftPane"><div class="HomepageSerp-fadeIn" style="opacity:0"></div></div><div class="HomepageSerp-rightPane RightPane"><div class="HomepageSerp-fadeIn" style="opacity:0"><div class="closerow RightPane-closeRow HomepageSerp-rightPaneCloseButton"><span class="closebutton RightPane-closeButton"><span><i class="fas fa-arrow-left"></i>Return to results</span></span></div></div></div></div>
# Job Title: None
# Job Link: []
# *** *** *** *** *** ***

# %% [markdown]
# Print out the contents of the job details dictionary

# %% [markdown]
# Assign the job details dictionary to a dataframe

# %% [markdown]
# Print out the first 5 rows of the dataframe

# %% [markdown]
# Establish a connection to your assignment_02 database.
#
# Append ?charset=utf8 to the database name to avoide codec errors.

# %% [markdown]
# Insert the dataframe contents to the simplyhired_job table you previously created.
#
# Ensure your variables in the jobs for loop matches the table's column names.
#
# Set the if_exists argument to append to insert into the table you already created.
#
# Do not insert the dataframe's index column.

# %% [markdown]
# ### Clear out the simplyhired_job table before proceeding.
# Run the following SQL in phpMyAdmin or TablePlus:
#
# TRUNCATE TABLE simplyhired_job;

# %% [markdown]
# ### Make 10 requests for the SimplyHired search page to scrape 100+ jobs and save the results to the simplyhired_job table
# A single job search request only returns ~10 jobs. Use the pn parameter to "paginate" through the results.
#
# The range function returns a range of numbers. range(1,11) returns 1-10.
#
# Replace the placeholders denoted by \~ALL_CAPS\~.

# %%
for ~PAGE_VARIABLE~ in range(1,11):
    print('Page:', ~PAGE_VARIABLE~)
    
    url = ~WEB_PAGE_URL~
    params = {'q':~KEYWORD~, 'pn':~PAGE_VARIABLE~}
    
    ~MAKE_WEB_PAGE_REQUEST~
    
    ~CREATE_BEAUTIFULSOUP_OBJECT_TO_PARSE_WEB_PAGE~

    ~FIND_ALL_JOBS_AND_ASSIGN_TO_A_VARIABLE~

    ~INITIALIZE_DICTIONARY_TO_STORE_JOB_DETAILS~

    ~LOOP_THROUGH_JOBS~
    
        ~TITLE~

        ~COMPANY~

        ~LOCATION~

        ~LINK~

        ~PRINT_NONALPHANUMERIC_JOB_DELIMITER~
        
    ~ASSIGN_JOBS_DICTIONARY_TO_A_DATAFRAME~
    
    ~INSERT_DATAFRAME_INTO_simplyhired_job_TABLE_WITH_if_exists_append_OPTION~

# %% [markdown]
# Confirm 100+ jobs were properly inserted into the simplyhired_job table. No need to provide proof. I will be running a SELECT on the table.
